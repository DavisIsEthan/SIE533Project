# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import fbeta_score
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

### Import data
inpath = r'C:/Users/Davis/Downloads/magic04data.csv'
df = pd.read_csv(inpath)

Y = np.array(df.pop("Class"))
X = np.array(df)

### split into train and test data, with ~1/3 of data reserved for testing
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.33, random_state = 11)

print(X_train)
# Out:
# [[ 35.6385  15.6583   2.8722 ...   5.8585  20.924   60.418 ]
#  [ 32.5973  13.8445   2.4786 ... -13.3874   7.556  206.229 ]
#  [ 20.3884   9.4149   2.2625 ... -10.0237  23.077  135.667 ]
#  ...
#  [ 25.8227  18.289    2.8146 ...  -2.6258   3.18   147.781 ]
#  [ 69.2105  35.8748   3.7178 ... -17.1281   3.301  283.857 ]
#  [ 42.3739  12.7034   2.5484 ...  -6.5528   7.1396 153.646 ]]

# %%
clf60ex = RandomForestClassifier(n_estimators = 200, max_depth = 60)

# %%
clf60ex.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=60, n_estimators=200)

# %%
y_p5 = clf5.predict(X_test)

cfd5 = (confusion_matrix(y_test, y_p5))
print(cfd5)

ConfusionMatrixDisplay.from_predictions(y_test, y_p5)
f2_5 = fbeta_score(y_test, y_p5, beta = 0.5)
print(f2_5)
rfc_disp = RocCurveDisplay.from_estimator(clf5, X_test, y_test, alpha=0.8)
plt.show()
# Out:
# [[1333  848]
#  [ 180 3916]]
# 0.8457152729785763

# %%
y_p8 = clf8.predict(X_test)

cfd8 = (confusion_matrix(y_test, y_p8))
print(cfd8)

ConfusionMatrixDisplay.from_predictions(y_test, y_p8)
f2_8 = fbeta_score(y_test, y_p8, beta = 0.5)
print(f2_8)
rfc_disp = RocCurveDisplay.from_estimator(clf8, X_test, y_test, alpha=0.8)

plt.show()
# Out:
# [[1482  699]
#  [ 184 3912]]
# 0.8677905944986691

# %%
y_p10 = clf10.predict(X_test)

cfd10 = (confusion_matrix(y_test, y_p10))
print(cfd10)

cfm = ConfusionMatrixDisplay.from_predictions(y_test, y_p10)
cfm.figure_.savefig(r'C:/Users/Davis/Desktop/DevComPresentationMaterials/cf10.pdf', dpi = 300)
f2_10 = fbeta_score(y_test, y_p10, beta = 0.5)
print(f2_10)

rfc_disp = RocCurveDisplay.from_estimator(clf10, X_test, y_test, alpha=0.8)
plt.show()
# Out:
# [[1563  618]
#  [ 197 3899]]
# 0.8795794982855081

# %%
y_p20 = clf20.predict(X_test)

cfd20 = (confusion_matrix(y_test, y_p20))
print(cfd20)

cfm = ConfusionMatrixDisplay.from_predictions(y_test, y_p20)
cfm.figure_.savefig(r'C:/Users/Davis/Desktop/DevComPresentationMaterials/cf20.png', dpi = 300)
f2_20 = fbeta_score(y_test, y_p20, beta = 0.5)
print(f2_20)

rfc_disp = RocCurveDisplay.from_estimator(clf20, X_test, y_test, alpha=0.8)
# Out:
# [[1660  521]
#  [ 234 3862]]
# 0.8928241168855189

# %%
y_p25 = clf25.predict(X_test)

ConfusionMatrixDisplay.from_predictions(y_test, y_p25)
f2_25 = fbeta_score(y_test, y_p25, beta = 0.5)
print(f2_25)
rfc_disp = RocCurveDisplay.from_estimator(clf25, X_test, y_test, alpha=0.8)
# Out:
# 0.893486732232325

# %%
y_p50 = clf50.predict(X_test)

cfd50 = (confusion_matrix(y_test, y_p50))
print(cfd50)

ConfusionMatrixDisplay.from_predictions(y_test, y_p50)
f2_50 = fbeta_score(y_test, y_p50, beta = 0.5)
print(f2_50)
rfc_disp = RocCurveDisplay.from_estimator(clf50, X_test, y_test, alpha=0.8)
# Out:
# [[1668  513]
#  [ 236 3860]]
# 0.8940151936260884

# %%
y_p60 = clf60.predict(X_test)
from sklearn.metrics import ConfusionMatrixDisplay

cfd60 = (confusion_matrix(y_test, y_p60))
print(cfd60)

cfm = ConfusionMatrixDisplay.from_predictions(y_test, y_p60)
cfm.figure_.savefig(r'C:/Users/Davis/Desktop/DevComPresentationMaterials/cf60.png', dpi = 300, transparent = True)
f2_60 = fbeta_score(y_test, y_p60, beta = 0.5)
print(f2_60)
rfc_disp = RocCurveDisplay.from_estimator(clf60, X_test, y_test, alpha=0.8)
# Out:
# [[1682  499]
#  [ 235 3861]]
# 0.896406017830609

# %%
y_p60ex = clf60ex.predict(X_test)
from sklearn.metrics import ConfusionMatrixDisplay


ConfusionMatrixDisplay.from_predictions(y_test, y_p60ex)
f2_60ex = fbeta_score(y_test, y_p60ex, beta = 0.5)
print(f2_60ex)
rfc_disp = RocCurveDisplay.from_estimator(clf60ex, X_test, y_test, alpha=0.8)
# Out:
# 0.8937823834196892

# %%
y_p75 = clf75.predict(X_test)
from sklearn.metrics import ConfusionMatrixDisplay


ConfusionMatrixDisplay.from_predictions(y_test, y_p75)
f2_75 = fbeta_score(y_test, y_p75, beta = 0.5)
print(f2_75)
rfc_disp = RocCurveDisplay.from_estimator(clf75, X_test, y_test, alpha=0.8)
# Out:
# 0.8947441601779756

# %%
from sklearn.model_selection import validation_curve
param_range = np.linspace(5, 60, 12)
train_scores, test_scores = validation_curve(
    RandomForestClassifier(),
    X_train,
    y_train,
    param_name="max_depth",
    param_range=param_range,
    scoring="roc_auc",
    n_jobs=5,
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
plt.title("ROC AUC for Random Forests of Varying Depth")
plt.xlabel(r"Max Depth")
plt.ylabel("AUC")
plt.ylim(0.85, 1.0)
plt.xlim(1, 80)
lw = 2
x = np.array([5, 8, 10, 25, 50, 60, 75])
y = np.array([.90, .92, .92, .93, .93, .93, .93])
plt.plot(x, y, label = 'AUC')
plt.legend(loc="best")
plt.savefig(r'C:/Users/Davis/Desktop/DevComPresentationMaterials/RFEROCAUC.png', dpi = 300)
plt.show()

# %%
plt.title(r"F$\beta$ Scores for Random Forests of Varying Depth, $\beta = 0.5$")
plt.xlabel(r"Max Depth")
plt.ylabel(r"F$\beta$")
plt.ylim(0.83, 0.91)
plt.xlim(1, 80)
lw = 2
x = np.array([5, 8, 10, 25, 50, 60, 75])
y = np.array([0.845715272978576, 0.867790594498669, 0.879579498285508, 
              0.893486732232325, 0.894015193626088, 0.896406017830609, 0.894744160177975])
plt.plot(x, y, label = r'F$\beta$')
plt.legend(loc="best")
plt.savefig(r'C:/Users/Davis/Desktop/DevComPresentationMaterials/RFEFbeta.png', dpi = 300)
plt.show()
